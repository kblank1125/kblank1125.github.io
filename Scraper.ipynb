# %% [markdown]
# <a href="https://colab.research.google.com/github/kblank1125/kblank1125.github.io/blob/main/Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# // Web scraping: 
import requests
from bs4 import BeautifulSoup
# // OS. Sometimes need this for finding working directory:
import os

# %%
url='https://en.wikipedia.org/wiki/UEFA_Champions_League'

# %%
pd.read_html(url)
table=pd.read_html(url)

# %%
table[3]
df=table[3]

# %%
df.to_json('UEFA_winner.json')

# %%
df.to_csv('UEFA_winner.csv')

# %%
pd.read_json('UEFA_winner.json')
# Out:
#                         Club  ...                         Seasons runner-up
# 0                Real Madrid  ...                          1962, 1964, 1981
# 1                      Milan  ...                    1958, 1993, 1995, 2005
# 2              Bayern Munich  ...              1982, 1987, 1999, 2010, 2012
# 3                  Liverpool  ...                          1985, 2007, 2018
# 4                  Barcelona  ...                          1961, 1986, 1994
# 5                       Ajax  ...                                1969, 1996
# 6          Manchester United  ...                                2009, 2011
# 7                Inter Milan  ...                                1967, 1972
# 8                   Juventus  ...  1973, 1983, 1997, 1998, 2003, 2015, 2017
# 9                    Benfica  ...              1963, 1965, 1968, 1988, 1990
# 10                   Chelsea  ...                                      2008
# ...

# %%
pd.read_csv('UEFA_winner.csv')
# Out:
#     Unnamed: 0  ...                         Seasons runner-up
# 0            0  ...                          1962, 1964, 1981
# 1            1  ...                    1958, 1993, 1995, 2005
# 2            2  ...              1982, 1987, 1999, 2010, 2012
# 3            3  ...                          1985, 2007, 2018
# 4            4  ...                          1961, 1986, 1994
# 5            5  ...                                1969, 1996
# 6            6  ...                                2009, 2011
# 7            7  ...                                1967, 1972
# 8            8  ...  1973, 1983, 1997, 1998, 2003, 2015, 2017
# 9            9  ...              1963, 1965, 1968, 1988, 1990
# 10          10  ...                                      2008
# 11          11  ...                                         —
# 12          12  ...                                         —
# 13          13  ...                                      1970
# ...
